# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\anushka\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\anushka\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\anushka\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\anushka\anaconda3\lib\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in c:\users\anushka\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\anushka\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Anushka\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Anushka\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Anushka\anaconda3\Lib\site-packages)

# %%
corpus = """Hello , Welcome Anushka !  
I am learning AI , ML and NLP .
Today is my birthday ."""

# %%
print(corpus)
# Out:
# Hello , Welcome Anushka !
# I am learning AI , ML and NLP .
# Today is my birthday .

# %% [markdown]
# ## Tokenization
# ## Sentence --> Paragraph

# %%
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello , Welcome Anushka !
# I am learning AI , ML and NLP .
# Today is my birthday .

# %% [markdown]
# ## Tokenization
# ## Paragraph --> Words
# ## Sentence --> Words

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Welcome',
#  'Anushka',
#  '!',
#  'I',
#  'am',
#  'learning',
#  'AI',
#  ',',
#  'ML',
#  'and',
#  'NLP',
#  '.',
#  'Today',
#  'is',
#  'my',
#  'birthday',
#  '.']

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello , Welcome Anushka !
# I am learning AI , ML and NLP .
# Today is my birthday .

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Welcome',
#  'Anushka',
#  '!',
#  'I',
#  'am',
#  'learning',
#  'AI',
#  ',',
#  'ML',
#  'and',
#  'NLP',
#  '.',
#  'Today',
#  'is',
#  'my',
#  'birthday',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Welcome',
#  'Anushka',
#  '!',
#  'I',
#  'am',
#  'learning',
#  'AI',
#  ',',
#  'ML',
#  'and',
#  'NLP',
#  '.',
#  'Today',
#  'is',
#  'my',
#  'birthday',
#  '.']
