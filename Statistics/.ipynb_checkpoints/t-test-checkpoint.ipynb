# %%
from scipy.stats import ttest_1samp

# %%
data = [52,54,53,55,56,
        54,53,55,54,52,
        56,55,54,53,52,
        55,54,56,53,54]

# %%
t_stat, p_value = ttest_1samp(data, popmean=50)

# %%
print("T Statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T Statistic: 13.784048752090223
# P-value: 2.4114090641721433e-11

# %%
from scipy.stats import ttest_ind

# %%
group1 = [80,82,85,88,90]
group2 = [75,78,79,80,82]

# %%
t_stat, p_value = ttest_ind(group1, group2)

# %%
print("T Statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T Statistic: 2.8477543154826783
# P-value: 0.02155335993278313

# %%
from scipy.stats import ttest_rel

# %%
before = [60,65,70,75,80]
after  = [65,68,75,80,85]

# %%
t_stat, p_value = ttest_rel(before, after)

# %%
print("T Statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T Statistic: -11.5
# P-value: 0.00032642125636699325
