# %%
from scipy.stats import f_oneway

# %%
group1 = [75,78,80,82]
group2 = [85,87,90,88]
group3 = [70,72,74,73]

# %%
f_stat, p_value = f_oneway(group1, group2, group3)

# %%
print("F-Statistic:", f_stat)
print("P-value:", p_value)
# Out:
# F-Statistic: 43.46907216494845
# P-value: 2.3720857239502985e-05
