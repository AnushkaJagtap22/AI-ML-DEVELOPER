# %%
# This is a single line comment
print("hello world")
# Out:
# hello world

# %%
# variables
nyc = 12
print(nyc)

#camel case
anushkaJG = 12
#pascal case
AnushkaJG = 12
#snake case
anushka_j_g = 12
# Out:
# 12

# %%
# data types
#numbers - integer , float , complex
a = 5
b = 5.0
c = 2 + 4j

print(type(a))
print(type(b))
print(type(c))

#sequence - string , list , tuple
s = 'Welcome to the Geeks World'
print(s)
print(type(s))
a = [1, 2, 3]
print(a)

b = ["Geeks", "For", "Geeks", 4, 5]
print(b[3])
print(b[-3])
t1 = (1,)
print(type(t1))

t2 = ('Geeks', 'For', 'Geeks', 1, 2)
print(t2[3])
print(t2[-3])
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# Welcome to the Geeks World
# <class 'str'>
# [1, 2, 3]
# 4
# Geeks
# <class 'tuple'>
# 1
# Geeks

# %%
# Boolean - True / False
print(type(True))
print(type(False))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
#set
s1 = {"a", "a", "b", "c", "b"}
print(s1)

s2 = {"Geeks", "For", "Geeks"}
for i in s2:
    print(i)
# Out:
# {'c', 'b', 'a'}
# For
# Geeks

# %%
#dictionary 
d = {1: 'Geeks', 2: 'For', 3: 'Geeks'}
print(d[1])    
print(d.get(2))
# Out:
# Geeks
# For

# %%
# string and type conversion
a = " "

print(ord(a))

a = "Hello how are you"

#how 

#you

#Hello




#type conversion 

#a = "12.5"
#a = int(a)

print(a)

#you can convert string if it holds valid integers
#you can convert float values to int

a = 143

#a = float(a)
#print(a)

a = 123
b = 34.5
c = 12 + 34j
d = True

a = str(a)
b = str(b)
c = str(c)
d = str(d)


a = 12 
b = 0 
c = 12.4
d = 0.0 
e = ""
f = "hello"
print(bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
print(bool(e))
print(bool(f))

a = 12 
print(a/2)
# Out:
# 32
# Hello how are you
# True
# False
# True
# False
# False
# True
# 6.0

# %%
# Input , Output , Operator

name = "akarsh" 
age = 24

print("hi my name is",name,"and my age is",age)

age = int(input("what is your age :- "))


print(f"hello your age is {age+24}")

#Arithmetic Operators
#numbers - int , float , complex
#(+, - , / ,//, *, ** ,%)'

a = 10 
b = 20
c = 12 
d = 56
print(a+b+c + d +23 + 56)
a = 34
print(a - 12)


a= 15
print(a//2)

print(12*12)


print(10000**1000)

print(37%5)

"""
() — Brackets
** — Exponent (right to left: 2**2**3 = 2**(2**3))
* / // % — Multiplication, Division, Floor Division, Modulus
+ - — Addition, Subtraction
"""
print(10 / 2 * 5)
print(10 * 2 / 5)




print(3 + 4 * 2)
print(15 // 4 + 15 % 4)
print(3 + 2 ** 2 * 5 - 1)

#comparision operators 

#(==, > , < >= , <= , !=)

print(16 == 16)
print(12 > 14)
print(12 < 45)
print(12 >= 12)
print(45 <= 56)

print(23 != 23)

print(23 != 56)

#and or and not

print(12 > 10 and 34 == 34 and 45 == 45 and 10 > 20)

print(34 == 45 or 12 == 23 or 67 == 69 or 12 ==12)

print(not 12 == 34)


print((5 > 3 and 10 == 10) or (4 != 4 and 2 < 1))




print((10 == 10 and 23 != 23) or (34 == 12 and bool("hello")))




print(not (5 == 5 and 3 != 4) or (10 > 20))




a = 10 

a += 10
a += 10 
a += 10

print(a)
name = "akarsh" 
age = 24

print("hi my name is",name,"and my age is",age)

age = int(input("what is your age :- "))


print(f"hello your age is {age+24}")

#Arithmetic Operators
#numbers - int , float , complex
#(+, - , / ,//, *, ** ,%)'
a = 10 
b = 20
c = 12 
d = 56
print(a+b+c + d +23 + 56)
a = 34
print(a - 12)


a= 15
print(a//2)

print(12*12)


print(10000**1000)

print(37%5)

"""
() — Brackets
** — Exponent (right to left: 2**2**3 = 2**(2**3))
* / // % — Multiplication, Division, Floor Division, Modulus
+ - — Addition, Subtraction
"""
print(10 / 2 * 5)
print(10 * 2 / 5)




print(3 + 4 * 2)
print(15 // 4 + 15 % 4)
print(3 + 2 ** 2 * 5 - 1)

#comparision operators 

#(==, > , < >= , <= , !=)

print(16 == 16)
print(12 > 14)
print(12 < 45)
print(12 >= 12)
print(45 <= 56)

print(23 != 23)

print(23 != 56)

#and or and not

print(12 > 10 and 34 == 34 and 45 == 45 and 10 > 20)

print(34 == 45 or 12 == 23 or 67 == 69 or 12 ==12)

print(not 12 == 34)


print((5 > 3 and 10 == 10) or (4 != 4 and 2 < 1))




print((10 == 10 and 23 != 23) or (34 == 12 and bool("hello")))




print(not (5 == 5 and 3 != 4) or (10 > 20))




a = 10 

a += 10
a += 10 
a += 10

print(a)
# Out:
# hi my name is akarsh and my age is 24
# what is your age :-  21
# hello your age is 45
# 177
# 22
# 7
# 144
# ...
# 2
# 25.0
# 4.0
# 11
# 6
# 22
# True
# False
# True
# True
# True
# False
# True
# False
# True
# True
# True
# False
# False
# 40
# hi my name is akarsh and my age is 24
# what is your age :-  21
# hello your age is 45
# 177
# 22
# 7
# 144
# ...
# 2
# 25.0
# 4.0
# 11
# 6
# 22
# True
# False
# True
# True
# True
# False
# True
# False
# True
# True
# True
# False
# False
# 40

# %%
# if else
#you have to take input of age and tell the 
# person can vote or not


age = int(input("please tell your age :- "))
if age >= 18:
    print("hello brother you can vote")
else:
    print("hello you can not vote sorry")

rupees = int(input(" give money - "))


if rupees == 10:
    print("I will have a chocobar")
elif rupees == 50:
    print("i will have manchurian")
elif rupees == 100:
    print("mcd")
elif rupees == 500:
    print("5 star dhaba")
else:
    print("bhuka rahu ga mai ")



#question 1 
num1 = int(input("please give me first number :- "))
num2 = int(input("please give me second number :- "))

if num1 > num2:
    print(f"{num1} is greater than {num2}")
elif num2 > num1:
    print(f"{num2} is greater than {num1}")
else:
    print("both the numbers are equal")

#question 2 

print("hello" > "hEllo") 

print(ord("h"))
print(ord("H"))

gen = input("please tell your gender in (M or F) :- ")

if gen == "M" or gen == "m":
    print("hello sir ")
elif gen == "F" or gen == "f":
    print("hello mam")
else:
    print("others")


a = int(input("please tell your number :- "))

if a %2 ==0:
    print("even number")
else:
    print("the number is odd")

name = input("please tell your name :- ")
age = int(input("please tell your age :- "))

if age >= 18:
    print(f"hello {name} you are a valid voter")
else:
    print(f"hello {name} you can vote after {18 - age} years")


year = int(input("please tell your year :- "))

if year %100 == 0 and year %400 == 0:
    print("leap year ")
elif year % 100 != 0 and year %4 ==0:
    print("leap year")
else:
    print("not a leap year")

temp = int(input("please tell your temprature:- "))

if temp >= -5 and temp <= 5:
    print("very cold")
elif temp >= 6 and temp <= 18:
    print("cold")
elif temp >= 19 and temp<= 30:
    print("hot")
else:
    print("very hot")
# Out:
# please tell your age :-  21
# hello brother you can vote
#  give money -  3000
# bhuka rahu ga mai
# please give me first number :-  21
# please give me second number :-  24
# 24 is greater than 21
# True
# 104
# 72
# please tell your gender in (M or F) :-  F
# hello mam
# please tell your number :-  3
# the number is odd
# please tell your name :-  4
# please tell your age :-  21
# hello 4 you are a valid voter
# please tell your year :-  2005
# not a leap year
# please tell your temprature:-  3
# very cold
