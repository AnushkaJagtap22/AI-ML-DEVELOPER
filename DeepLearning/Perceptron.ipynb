# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import Perceptron
from sklearn.preprocessing import LabelEncoder
from mlxtend.plotting import plot_decision_regions

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Using cached mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\anushka\anaconda3\lib\site-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\anushka\anaconda3\lib\site-packages (from mlxtend) (2.3.5)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\anushka\anaconda3\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\anushka\anaconda3\lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\anushka\anaconda3\lib\site-packages (from mlxtend) (3.10.9)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\anushka\anaconda3\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anushka\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\anushka\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anushka\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anushka\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\anushka\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\anushka\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\anushka\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anushka\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anushka\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anushka\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\anushka\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\anushka\anaconda3\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)
# Using cached mlxtend-0.24.0-py3-none-any.whl (1.4 MB)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.24.0
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Anushka\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Anushka\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Anushka\anaconda3\Lib\site-packages)

# %%
# Load dataset
df = pd.read_csv("iris.csv")

# %%
# Display first 5 rows
print(df.head())
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
# Select only 2 features
X = df[['sepal.length', 'petal.length']].values

# %%
# Target column
y = df['variety']

# %%
# Convert string labels into numbers
le = LabelEncoder()
y = le.fit_transform(y)

# %%
# Create Perceptron model
p = Perceptron()

# %%
# Train model
p.fit(X, y)
# Out:
# Perceptron()

# %%
# Accuracy
print("Training Accuracy:", p.score(X, y))
# Out:
# Training Accuracy: 0.66

# %%
# Plot decision boundary
plot_decision_regions(X, y, clf=p)
# Out:
# <Axes: >

# %%
# Labels
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.title("Perceptron Decision Boundary")
# Out:
# Text(0.5, 1.0, 'Perceptron Decision Boundary')

# %%
# Show plot
plt.show()
